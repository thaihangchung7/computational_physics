# %%
import matplotlib.pyplot as plt

# %%
from vpython import *
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
x=0.5
rarray = []
xarray = []
for r in arange(2,4,.001):
    for t in arange(0,200):
        x=r*x*(1-x)
        rarray.append(r)
        xarray.append(x)

# %%
plt.plot(rarray,xarray,linewidth=0.2,)
plt.rcParams["figure.figsize"] = (20,10)
